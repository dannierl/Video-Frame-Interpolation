# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
import numpy as np
from matplotlib import pyplot as plt

from helper import Helper
# from img_transformer import ImgTransformer
from adaConv import adaConv

helper = Helper()
data_path = "./dataset/vimeo_triplet/"
train_image = helper.load_image(data_path, 1, 3)

model = adaConv()
# Out:
# Using TensorFlow backend.
# Limit GPU memory ...
# RTX optimizer is on ...

# %%
# model.ada_conv_train(train_image)

# %%
plt.imshow(train_image[0][1])

# %%
train_image2 = helper.load_image(data_path, 2, 3)
plt.imshow(train_image2[0][1])

# %%
predicted_frames = model.ada_conv_predict(train_image2)

predicted_frames = predicted_frames.astype(dtype=np.uint8)
plt.imshow(predicted_frames)
# Out:
# Loaded model from ./model/test.hdf5

# %%
# diff = train_image[0][1] - predicted_frames
# print(diff)
